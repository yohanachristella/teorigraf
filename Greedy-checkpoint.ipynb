# %%
import time 

start_time = time.time()

def check_color(color_list):
    color = 1
    while True:
        if color not in color_list:
            return color
        color += 1


def get_neighbors(graph, vertex):
    i = vertex
    neighbors_list = graph[i]
    return neighbors_list


def get_colors(colors, neighbors):
    neighbor_colors = []
    for n in neighbors:
        if colors.__contains__(n):
            neighbor_colors.append(colors[n])
    return neighbor_colors


def greedy(graph, vertices):
    colors = {}
    for vertex in vertices:
        v = get_neighbors(graph, vertex)
        if any(key in colors for key in v):
            neighbor_colors = get_colors(colors, v)
            colors[vertex] = check_color(neighbor_colors)
        else:
            colors[vertex] = 1
    print(colors)
    return(colors)


print("Execution time :  %s seconds " % (time.time() - start_time))

# greedy({'A': ['B'], 'B': ['A', 'C'], 'C': ['B', 'D'], 'D': ['C']}, ['A', 'D', 'B', 'C'])
greedy({'1':['43'], '2':['19','73'], '3':['65'], '4':['38','46','67'], '5':['21','76','83'], '6':['22','40'], '7':['15'], '8':['16','24','60'], '9':['0'],'10':['52','63','71','80','93'], '11':['0'], '12':['45','74'], '13':['32','75','81'], '14':['47'], '15':['7'], '16':['8','24','60'], '17':['0'], '18':['26','53','72','30','86','94'], '19':['2','73'], '20':['82'], '21':['5','76','83'], '22':['6','40'], '23':['0'], '24': ['8','16','60'], '25':['0'], '26':['18','53','72','30','86','94'], '27':['0'], '28':['0'], '29':['50','61','85','92'], '30':['18','26','53','72','86','94'], '31':['54','87'], '32':['13','75','81'], '33':['56','97'], '34':['0'], '35':['0'], '36':['51'], '37':['64'], '38':['4','46','67'], '39':['0'], '40':['6','22'], '41':['59','107'], '42':['0'], '43':['1'], '44':['0'], '45':['12','74'], '46':['4','38','67'], '47':['14'], '48':['78'], '49':['0'], '50':['29','61','85','92'], '51':['36'], '52':['10','63','71','80','93'], '53':['18','26','72','30','86','94'], '54':['31','87'], '55':['66','96'], '56':['33','97'], '57':['69','77','89'], '58':['0'], '59':['41','107'], '60':['8','16','24'], '61':['50','29','85','92'], '62':['70','101'], '63':['10','52','71','80','93'], '64':['37'], '65':['3'], '66':['55','96'], '67':['4','38','46'], '68':['0'], '69':['57','77','89'], '70':['62','101'], '71':['10','52','63','80','93'], '72':['18','26','53','30','86','94'], '73':['2','19'], '74':['12','45'], '75':['13','32','81'], '76':['5','21','83'], '77':['57','69','89'], '78':['48'], '79':['0'], '80':['10','52','63','71','93'], '81':['13','32','75'], '82':['20'], '83':['5','21','76'], '84':['90'], '85':['50','29','61','92'], '86':['18','26','53','72','30','94'], '87':['31','54'], '88':['103'], '89':['57','69','77'], '90':['84'], '91':['100','108'], '92':['50','29','61','85'], '93':['10','52','63','71','80'], '94':['18','26','53','72','30','86'], '95':['0'], '96':['55','66'], '97':['33','56'], '98':['0'], '99':['0'], '100':['91','108'], '101':['62','70'], '102':['0'], '103':['88'], '104':['0'], '105':['0'], '106':['0'], '107':['41','59'], '108':['91','100'], '109':['0']    }, ['44', '25', '34', '68', '79', '58', '49', '39', '35', '95', '23', '27', '98', '99', '9', '28', '102', '11', '104', '105', '106', '42', '17', '109', '48', '14', '3', '15', '51', '20', '78', '43', '82', '36', '84', '88', '37', '90', '1', '7', '47', '103', '64', '65', '40', '41', '45', '54', '55', '56', '59', '2', '62', '66', '70', '31', '73', '74', '19', '33', '12', '6', '87', '91', '22', '96', '97', '100', '101', '107', '108', '21', '24', '32', '38', '46', '4', '57', '60', '16', '8', '67', '69', '5', '75', '76', '77', '81', '83', '89', '13', '29', '50', '61', '85', '92', '10', '52', '63', '71', '80', '93', '18', '26', '30', '53', '72', '86', '94'])
# Out:
# Execution time :  0.0 seconds
# ...
